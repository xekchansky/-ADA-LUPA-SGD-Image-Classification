# %%
#pip install ftputil #not used
#pip install numpy
#pip install matplotlib
#pip install pandas
#!pip install tensorflow --user
#!pip install --upgrade pip --user
#!pip install -q pyyaml h5py --user
#!pip install matplotlib
#!pip install sklearn

#import sys
#!{sys.executable} -m pip install tensorflow --user
#!pip3 install --upgrade tensorflow-gpu --user

# %% [markdown]
# folders: 654
#
# files in folder: 6972
#
# total files: 4559688
#
# target - additive ???
#
# unique values = 5
#
#     cGP       1059744
#     hG        1031856
#     cT         990024
#     hM         885444
#     hclear     592620
#     Name: additive, dtype: int64

# %%
import utils
import server
import worker

import math
import tensorflow as tf
from tensorflow.python.client import device_lib


#print(device_lib.list_local_devices())
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# LUPA-SGD
#
# p - num of workers\
# D - data size\
# $\tau$ - number of local updates before synchronization\
# $\eta_t$ - learning rate at t-iteration
#
# F(x) - loss function is L-smooth and sutisfies PL-condition:\
# $||\triangledown F(x) - \triangledown F(y)|| \leq L||x - y|| \\ \frac{1}{2}||\triangledown F(x)||_2^2 \geq \mu||F(x) - F(x^*)||$
#
#
#
# $k = \frac{L}{\mu}\\
# \alpha \geq O(max(\frac{1}{ln(\frac{D}{k^2}(\frac{k}{\tau}+D))};\frac{k}{\tau} + D))\\
# a = \alpha \tau + 4\\
# \eta_t = \frac{4}{\mu(t + a)}$

# %%
num_workers = 3
data_size = 24000
shard_size = 8000
minibatch_size = 128
epochs = 8
T = (shard_size / minibatch_size) * epochs
local_updates = int((T**(2/3))/((num_workers*minibatch_size)**(1/3)))
rounds = math.ceil(T / local_updates)


L = 1000
Mu = 0.001
k = L/Mu #condition number
alpha = max(1/math.log(data_size/(k**2) * (k/local_updates + data_size)), k/local_updates + data_size)
a = alpha * local_updates + 4
#learning_rate = 0.0001
#regularization_rate = 0.0001

print("total_iterations:", T)
print("local updates:", local_updates)
print("rounds of comms:", rounds)

serv = server.Server(num_workers=num_workers,
                     shard_size=shard_size,
                     #learning_rate=learning_rate,
                     #regularization_rate=regularization_rate,
                     debug=True)
serv.run(rounds=rounds,
         local_steps=local_updates,
         minibatch_size=minibatch_size, 
         Mu=Mu,
         a = a)

serv.plot_history()
# Out:
# total_iterations: 500.0
# local updates: 8
# rounds of comms: 63
# c:\users\xekch\.conda\envs\tf_gpu\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 256, 256, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 252, 252, 16)      416
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 126, 126, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 124, 124, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 60, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 32)          9248
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                16416
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 51,701
# Trainable params: 51,701
# Non-trainable params: 0
# _________________________________________________________________
# Preparing worker 0
# Getting data
# C:\Users\xekch\KURSACH PROJECT\worker.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shard_df['image'] = images
# Preprocessing
# Setting start model
# Setting initialization weights
# Done
#
# Preparing worker 1
# Getting data
# c:\users\xekch\.conda\envs\tf_gpu\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# Preprocessing
# Setting start model
# Setting initialization weights
# Done
#
# Preparing worker 2
# Getting data
# Preprocessing
# Setting start model
# Setting initialization weights
# Done
# C:\Users\xekch\KURSACH PROJECT\server.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shard_df['image'] = images
# Start of round 0
# learning rate: 0.0033556934372703444
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 0
# 10/10 - 1s - loss: 1.9283 - accuracy: 0.2433
# Model, accuracy: 24.33%
#
# Start of round 1
# learning rate: 0.0033556709160646033
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 1
# 10/10 - 0s - loss: 3.4480 - accuracy: 0.2767
# Model, accuracy: 27.67%
#
# Start of round 2
# learning rate: 0.0033556483951611552
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 2
# 10/10 - 0s - loss: 3.1035 - accuracy: 0.2167
# Model, accuracy: 21.67%
#
# Start of round 3
# learning rate: 0.0033556258745599935
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 3
# 10/10 - 0s - loss: 4.7813 - accuracy: 0.2133
# Model, accuracy: 21.33%
#
# Start of round 4
# learning rate: 0.0033556033542611126
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 42
# 10/10 - 0s - loss: 928167808.0000 - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 43
# learning rate: 0.0033547252983189475
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 43
# 10/10 - 0s - loss: 1650059392.0000 - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 44
# learning rate: 0.0033547027901063104
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 44
# 10/10 - 0s - loss: 2933416448.0000 - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 45
# learning rate: 0.0033546802821957052
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 45
# 10/10 - 0s - loss: 5214931968.0000 - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 46
# learning rate: 0.0033546577745871254
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 46
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 47
# learning rate: 0.0033546352672805648
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 47
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 48
# learning rate: 0.003354612760276018
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 48
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 49
# learning rate: 0.0033545902535734775
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 49
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 50
# learning rate: 0.0033545677471729382
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 50
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 51
# learning rate: 0.0033545452410743935
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 51
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 52
# learning rate: 0.003354522735277838
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 52
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 53
# learning rate: 0.0033545002297832656
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 53
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 54
# learning rate: 0.0033544777245906703
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 54
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 55
# learning rate: 0.0033544552197000447
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 55
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 56
# learning rate: 0.003354432715111384
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 56
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 57
# learning rate: 0.0033544102108246814
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 57
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 58
# learning rate: 0.003354387706839932
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 58
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 59
# learning rate: 0.003354365203157128
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 59
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 60
# learning rate: 0.0033543426997762658
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 60
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 61
# learning rate: 0.0033543201966973364
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 61
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%
#
# Start of round 62
# learning rate: 0.0033542976939203353
# Worker 0
# Worker 1
# Worker 2
# RESULTS OF ROUND 62
# 10/10 - 0s - loss: nan - accuracy: 0.2400
# Model, accuracy: 24.00%

# %%
#попытка подбора гиперпараметров

for plr in range(1, 6):
    for prr in range(3, 10):
        learning_rate = 10**-plr
        regularization_rate = 10**-prr
        print("learning rate:", learning_rate)
        print("regularization rate:", regularization_rate)
        serv = server.Server(num_workers=num_workers,
                             shard_size=shard_size,
                             learning_rate=learning_rate,
                             regularization_rate=regularization_rate,
                             debug=False)
        serv.run(rounds=rounds,
                 local_steps=local_updates,
                 minibatch_size=minibatch_size)
        serv.plot_history()
# Out:
# learning rate: 0.1
# regularization rate: 0.001
# learning rate: 0.1
# regularization rate: 0.0001
# learning rate: 0.1
# regularization rate: 1e-05
# learning rate: 0.1
# regularization rate: 1e-06
# learning rate: 0.1
# regularization rate: 1e-07
# learning rate: 0.1
# regularization rate: 1e-08
# learning rate: 0.1
# regularization rate: 1e-09
# learning rate: 0.01
# regularization rate: 0.001
# learning rate: 0.01
# regularization rate: 0.0001
# learning rate: 0.01
# regularization rate: 1e-05
# learning rate: 0.01
# regularization rate: 1e-06
# learning rate: 0.01
# regularization rate: 1e-07
# learning rate: 0.01
# regularization rate: 1e-08
# learning rate: 0.01
# regularization rate: 1e-09
# learning rate: 0.001
# regularization rate: 0.001
# learning rate: 0.001
# regularization rate: 0.0001
# learning rate: 0.001
# regularization rate: 1e-05
# learning rate: 0.001
# regularization rate: 1e-06
# learning rate: 0.001
# regularization rate: 1e-07
# learning rate: 0.001
# regularization rate: 1e-08
# learning rate: 0.001
# regularization rate: 1e-09
# learning rate: 0.0001
# regularization rate: 0.001
# learning rate: 0.0001
# regularization rate: 0.0001
# learning rate: 0.0001
# regularization rate: 1e-05
# learning rate: 0.0001
# regularization rate: 1e-06
# learning rate: 0.0001
# regularization rate: 1e-07
# learning rate: 0.0001
# regularization rate: 1e-08
# learning rate: 0.0001
# regularization rate: 1e-09
# learning rate: 1e-05
# regularization rate: 0.001
# learning rate: 1e-05
# regularization rate: 0.0001
# learning rate: 1e-05
# regularization rate: 1e-05
# learning rate: 1e-05
# regularization rate: 1e-06
# learning rate: 1e-05
# regularization rate: 1e-07
# learning rate: 1e-05
# regularization rate: 1e-08
# learning rate: 1e-05
# regularization rate: 1e-09
